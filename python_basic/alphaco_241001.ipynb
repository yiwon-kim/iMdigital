# %%
import yfinance as yf
apple = yf.download('AAPL', start='2020-01-01', end = '2024-09-30')
nvidia = yf.download('NVDA', start='2020-01-01', end = '2024-09-30')
intel = yf.download('INTC', start='2020-01-01', end = '2024-09-30')
AMD = yf.download('AMD', start='2020-01-01', end = '2024-09-30')

AMD.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-01-02  46.860001  49.250000  46.630001  49.099998  49.099998  80331100
# 2020-01-03  48.029999  49.389999  47.540001  48.599998  48.599998  73127400
# 2020-01-06  48.020000  48.860001  47.860001  48.389999  48.389999  47934900
# 2020-01-07  49.349998  49.389999  48.040001  48.250000  48.250000  58061400
# 2020-01-08  47.849998  48.299999  47.139999  47.830002  47.830002  53767000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 데이터
dates = [
    '2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04', '2021-01-05',
    '2021-01-06', '2021-01-07', '2021-01-08', '2021-01-09', '2021-01-10'
]
min_temperature = [20.7, 17.9, 18.8, 14.6, 15.8, 15.8, 15.8, 17.4, 21.8, 20.0]
max_temperature = [34.7, 28.9, 31.8, 25.6, 28.8, 21.8, 22.8, 28.4, 30.8, 32.0]

fig, ax = plt.subplots(nrows = 2, ncols =2, figsize=(10,4))

ax[1,1].plot(dates, min_temperature, marker="o", label='min_temp')
plt.tight_layout()

# %% [markdown]
# # 야후 무료 주식 차트 가져오기

# %%
import yfinance as yf
data = yf.download('AAPL', start='2020-01-01', end = '2024-09-30')

fig, ax = plt.subplots()
ax.plot(data['Open'])

plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data2 = data.copy() # 데이터 카피 해서 원본 데이터 안바뀌게 사용

data2 = data.reset_index()
data2.head(1)

fig, ax = plt.subplots()
#ax.plot(data2['Open']) # x축에 숫자로 나오면 index가 숫자로 되어 있다라고 생각하면 됨

# x축날짜로 하고 싶은데, 다른게 나오면, set_index로 날짜 지정 또는 날짜까지 2개 써줘야함
ax.plot(data2['Date'], data2['Open']) # 1 x축 y 축 지정
data2.set_index('Date') # 2 set_index로 x축 index 변경 후 y축만 지정
plt.show()
